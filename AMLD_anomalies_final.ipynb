# %% [markdown]
# ## Setup Google Colab

# %%
#@title << Setup Google Colab by running this cell {display-mode: "form"}
import sys
if 'google.colab' in sys.modules:
    # Clone GitHub repository
    # !git clone https://github.com/pacm/video-search.git
        
    # Copy files required to run the code
    # !cp -r "video-search/data" "video-search/helpers.py" .
    
    # Install packages via pip
    # !pip install -r "video-search/colab-requirements.txt"
    
    # Restart Runtime
    import os
    os.kill(os.getpid(), 9)

# %% [markdown]
# ## Create dataset

# %%
# %run anomaly_helpers.py

dataset=create_dataset()
# Out:
# Number of training samples to be used:
# Please choose a number between 100 and 80819
#   20000
# Portion of training samples to be attacks:
# Please choose a number between 0 and 0.5 .
#   0
# Your training set has the following composition:
#         frequency
# class
# normal      20000

# %% [markdown]
# ## Visualise 1000 samples of the training data

# %%
visualise_training_data(dataset)
# Out:
# Plotting 1000 samples of the training data

# %% [markdown]
# ## Train and evaluate your anomaly detector

# %%
# %run anomaly_helpers.py
build_and_evaluate_anomaly_detector(dataset, 
                                    IF_contamination=0.25,
                                    with_PCA = True)
# Out:
# Using PCA to transform data
# Summary report:
# Attacks identified correctly (true positive): 253  of  259 ( 97.7 %)
# Attacks missed (false negative): 6  of  259 ( 2.3 %)
# False alarms (false positive): 171  of 741 ( 23.1 %)
# Total number of misclassified samples: 177
# Detailed report:
#                present  missed  pct_missed
# attack_detail
# normal             741     171        23.1
# neptune             68       0         0.0
# satan               40       0         0.0
# ipsweep             40       0         0.0
# portsweep           32       0         0.0
# smurf               29       0         0.0
# nmap                16       2        12.5
# back                11       0         0.0
# warezclient         10       0         0.0
# teardrop            10       4        40.0
# pod                  2       0         0.0
# guess_passwd         1       0         0.0
# Plotting 1000 samples of the test data

# %% [markdown]
# ## TASKS:

# %% [markdown]
# ### TASK 1:
# **Vary the size and contamination level of  your training data.**
# **In particular see how the model performs on totally clean data**

# %% [markdown]
# ### TASK 2:
# **Vary the "IF_contamination" which is the parameter used by the model to make decisions**

# %% [markdown]
# ### TODO
# * Change test set visualisation to highlight misclassified
# true normal blue
# false normal dark blue
# true attack orange
# missed attack RED and BIG
